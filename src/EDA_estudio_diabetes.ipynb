# %% [markdown]
# # Explore here

# %%
import pandas as pd
import numpy as np
import importlib
import Auto_EDA as Auto_EDA
importlib.reload(Auto_EDA)

from Auto_EDA import (
    explore_data,
    clean_duplicates,
    clean_irrelevant_data,
    univariate_categorical_analysis,
    univariate_numerical_analysis,
    bivariate_numerical_analysis,
    bivariate_categorical_analysis,
    class_predictor_analysis,
    correlation_analysis,
    categorical_numerical_correlation,
    pairplot_analysis,
    analyze_outliers,
    replace_outliers,
    handle_missing_values,
    infer_new_features,
    feature_scaling,
    normalize_data,
    scale_min_max_data_1,
    feature_selection,
    target_column
)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/decision-tree-project-tutorial/main/diabetes.csv", sep=",")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## 1. Exploración y limpieza

# %%
explore_data(df)
# Out:
# Información general del dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
#
# Estadísticas descriptivas:
# (768, 9)
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# ...

# %% [markdown]
# Conclusiones:
#
# 1) El Dataframe contiente 768 filas (registros) y 9 columnas (Variables)
#
# En cuanto a la clasificación de los datos:
#
# * Características numéricas (9 en total)

# %% [markdown]
# ### 1.1 Quitar Duplicados

# %%
clean_duplicates(df)
# Out:
# Registros duplicados eliminados: 0
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# Conclusiones: Este DF no tiene registros duplicados.

# %% [markdown]
# ### 1.2 Eliminar información innecesaria

# %%
clean_irrelevant_data(df)
# Out:
# Columnas irrelevantes eliminadas: []
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# Conclusiones: Se considera que todas las columans obtiene información necesria, por lo que no se eliminan nada.

# %% [markdown]
# ## 2. Análisis de variables Univariadas

# %% [markdown]
# ### 2.1 Varbiables categóricas

# %%
univariate_categorical_analysis(df)
# Out:
# No hay columnas categóricas en el DataFrame para generar gráficos.

# %% [markdown]
# Conclusiones: No hay columnas categóricas en el DataFrame para generar gráficos.

# %% [markdown]
# ### 2.2 Variables Numéricas

# %%
univariate_numerical_analysis(df)

# %% [markdown]
# Conclusiones:
#
# 1) Distribución de Edad: Este gráfico revela una clara concentración de individuos jóvenes en el conjunto de datos, con una disminución marcada a medida que aumenta la edad.
# 2) Distribución de BMI: El gráfico del BMI muestra una distribución que tiende hacia el sobrepeso, con la mayoría de los individuos agrupados alrededor de un índice de masa corporal de 30.
# 3) Distribución de BloodPressure: El histograma revela una distribución de la presión sanguínea centrada en valores normales, con presencia de atípicos bajos que requieren consideración.
# 4) Distribución de DiabetesPedigreeFunction: Se observa una distribución asimétrica positiva de la función de pedigrí de diabetes, indicando una predominancia de valores bajos en la muestra.
# 5) Distribución de Glucose (Glucosa): El histograma muestra una distribución de glucosa con una concentración significativa en el rango medio, sugiriendo una distribución sesgada hacia valores elevados.
# 6) Distribución de Insulin (Insukina): La distribución de insulina presenta una marcada asimetría positiva, indicando una predominancia de valores bajos con una disminución exponencial hacia valores altos.
# 7) Distribución de Pregnancies (Embarazos): El histograma muestra una distribución sesgada positivamente, con una concentración significativa de individuos sin embarazos previos y una disminución gradual hacia un mayor número de embarazos.
# 8) Distribución de Skin Thickness (Grosor de la Piel): La distribución del grosor de la piel presenta una bimodalidad, con un pico principal en valores bajos y un segundo pico en un rango intermedio, indicando posibles subgrupos dentro de la población.

# %% [markdown]
# ## 3. Análisis de variables multivariante

# %% [markdown]
# ### 3.1 Numérico-numérico

# %%
bivariate_numerical_analysis(df)

# %% [markdown]
# Conclusiones:
#
# Por Edad:
#
# * Edad vs. BMI: Se observa una ligera tendencia a la disminución del BMI con la edad, aunque la dispersión de los datos es considerable.
# * Edad vs. Presión Sanguínea: Existe una tendencia al aumento de la presión sanguínea con la edad, aunque también hay una dispersión significativa.
# * Edad vs. Función de Pedigrí de Diabetes: La función de pedigrí de diabetes parece no mostrar una correlación clara con la edad, con una distribución dispersa de los datos.
# * Edad vs. Glucosa: Se observa una tendencia al aumento de los niveles de glucosa con la edad, aunque la dispersión es notable.
# * Edad vs. Insulina: La relación entre la edad y la insulina es compleja, con una dispersión amplia de los datos y una tendencia menos clara.
# * Edad vs. Embarazos: El número de embarazos tiende a concentrarse en edades más jóvenes, con una disminución a medida que aumenta la edad, como era de esperarse.
#
# Por BMI:
#
# * BMI vs. Grosor de la Piel: Se observa una tendencia al aumento del grosor de la piel con el aumento del BMI, aunque la relación no es estrictamente lineal.
# * BMI vs. Presión Sanguínea: Existe una correlación positiva entre el BMI y la presión sanguínea, lo que indica que la presión sanguínea tiende a aumentar con el aumento del BMI.
# * BMI vs. Función de Pedigrí de Diabetes: No se observa una correlación clara entre el BMI y la función de pedigrí de diabetes, con una distribución dispersa de los datos.
# * BMI vs. Glucosa: Se observa una tendencia al aumento de los niveles de glucosa con el aumento del BMI, lo que sugiere una posible relación entre el sobrepeso y la resistencia a la insulina.
# * BMI vs. Insulina: La relación entre el BMI y la insulina es compleja, con una dispersión amplia de los datos y una tendencia menos clara, aunque se percibe que los niveles de insulina tienden a aumentar con el aumento del BMI.
# * BMI vs. Embarazos: No se observa una correlación clara entre el BMI y el número de embarazos, con una distribución dispersa de los datos.
#
# Por presión Sanquínea:
#
# * Presión Sanguínea vs. BMI: Se observa una correlación positiva, lo que indica que la presión sanguínea tiende a aumentar con el aumento del BMI.
# * Presión Sanguínea vs. Función de Pedigrí de Diabetes: No se observa una correlación clara, con una distribución dispersa de los datos.
# * Presión Sanguínea vs. Glucosa: Se observa una tendencia al aumento de los niveles de glucosa con el aumento de la presión sanguínea.
# * Presión Sanguínea vs. Insulina: Se observa una tendencia al aumento de los niveles de insulina con el aumento de la presión sanguínea.
# * Presión Sanguínea vs. Embarazos: No se observa una correlación clara, con una distribución dispersa de los datos.
# * Presión Sanguínea vs. Grosor de la Piel: Se observa una tendencia al aumento del grosor de la piel con el aumento de la presión sanguínea.

# %% [markdown]
# ### 3.2 Categótico-categórico

# %%
bivariate_categorical_analysis(df)
# Out:
# No hay suficientes columnas categóricas en el DataFrame para realizar un análisis bivariante.

# %% [markdown]
# Conclusiones: No hay suficientes columnas categóricas en el DataFrame para realizar un análisis bivariante.

# %% [markdown]
# ### 3.3 Combinaciones de la clase con varias predictoras

# %%
class_predictor_analysis(df)
# Out:
# No hay suficientes columnas numéricas y/o categóricas para generar los gráficos.

# %% [markdown]
# Conclusiones: No hay suficientes columnas categóricas en el DataFrame para realizar un análisis bivariante.

# %% [markdown]
# ### 3.4 Análisis de correlaciones

# %%
correlation_analysis(df)

# %% [markdown]
# Conclusiones:
#
# La matriz de correlación muestra relaciones lineales entre variables médicas. Destacan correlaciones positivas moderadas entre:
#
# * Glucosa y Resultado (Outcome)
# * Edad y Embarazos (Pregnancies)
# * BMI y Presión Sanguínea (BloodPressure)
#
# Las demás correlaciones son débiles. Importante: correlación no implica causalidad.

# %% [markdown]
# ### 3.5 Categórico-numérico

# %%
categorical_numerical_correlation(df)
# Out:
# No hay suficientes columnas numéricas y/o categóricas para generar los gráficos de correlación.

# %% [markdown]
# Conclusiones: No hay suficientes columnas numéricas y/o categóricas para generar los gráficos de correlación.

# %% [markdown]
# ## 4. Análisis de toda la data en una

# %%
pairplot_analysis(df)

# %% [markdown]
# ## 5. Feature Engineering

# %% [markdown]
# ### 5.1 Análisis Outliers

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df_sin_outliers, numerical_cols = analyze_outliers(df)

# %%
df_sin_outliers = replace_outliers(df_sin_outliers, numerical_cols)
# Out:
# {'Age': [21.0, 66.5], 'BMI': [13.35, 50.550000000000004], 'BloodPressure': [35.0, 107.0], 'DiabetesPedigreeFunction': [0.078, 1.2], 'Glucose': [37.125, 202.125], 'Insulin': [0.0, 318.125], 'Pregnancies': [0.0, 13.5], 'SkinThickness': [0.0, 80.0]}

# %% [markdown]
# ### 5.2  Anáisis de valores faltantes

# %%
handle_missing_values(df_sin_outliers)
# Out:
# Valores faltantes por columna:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
#
# Valores faltantes después de la imputación:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.6
# 1            1.0     85.0           66.0           29.0      0.0  26.6
# 2            8.0    183.0           64.0            0.0      0.0  23.3
# ...

# %% [markdown]
# Conclusiones:

# %% [markdown]
# ### 5.3 Inferencia de nuevas caraterísticas

# %%
infer_new_features(df_sin_outliers)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.6
# 1            1.0     85.0           66.0           29.0      0.0  26.6
# 2            8.0    183.0           64.0            0.0      0.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            0.0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0      0.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            0.0      0.0  30.1
# 767          1.0     93.0           70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# ...

# %% [markdown]
# No hay columnas en el DF que pueda aplicarse para la inferencia de nuevas características

# %% [markdown]
# ## 6. Feature Scalling

# %%
X_train_con_outliers, X_test_con_outliers, X_train_sin_outliers, X_test_sin_outliers, y_train, y_test, numerical_cols= feature_scaling(df, df_sin_outliers)
# Out:
# Archivos creados: X_train_con_outliers.xlsx, X_train_sin_outliers.xlsx, X_test_con_outliers.xlsx, X_test_sin_outliers.xlsx, y_train.xlsx, y_test.xlsx

# %% [markdown]
# ### 6.1 Normalización

# %%
X_train_con_outliers_norm, X_test_con_outliers_norm, X_train_sin_outliers_norm, X_test_sin_outliers_norm = normalize_data(X_train_con_outliers, X_test_con_outliers, X_train_sin_outliers, X_test_sin_outliers, numerical_cols)
# Out:
# Archivos creados: X_train_con_outliers_norm.xlsx, X_test_con_outliers_norm.xlsx, X_train_sin_outliers_norm.xlsx, X_test_sin_outliers_norm.xlsx

# %% [markdown]
# ### 6.2 Escalado Mínimo-Máximo

# %%
X_train_con_outliers_scal, X_test_con_outliers_scal, X_train_sin_outliers_scal, X_test_sin_outliers_scal = scale_min_max_data_1(X_train_con_outliers, X_test_con_outliers, X_train_sin_outliers, X_test_sin_outliers, numerical_cols)
# Out:
# DataFrames escalados, modelos guardados y archivos XLSX creados.

# %% [markdown]
# ## 7. Feature Selection

# %% [markdown]
# ### 7.1 Selección de Características

# %%
feature_selection(X_train_con_outliers, X_test_con_outliers, X_train_sin_outliers, X_test_sin_outliers, X_train_con_outliers_norm, X_test_con_outliers_norm, X_train_sin_outliers_norm, X_test_sin_outliers_norm, X_train_con_outliers_scal, X_test_con_outliers_scal, X_train_sin_outliers_scal, X_test_sin_outliers_scal, y_train, y_test,target_column)
# Out:
# Características seleccionadas: ['Age', 'BMI', 'BloodPressure', 'DiabetesPedigreeFunction', 'Glucose', 'Insulin', 'Pregnancies', 'SkinThickness', 'Outcome']
# (      Age   BMI  BloodPressure  DiabetesPedigreeFunction  Glucose  Insulin  \
#  0    21.0   0.0            0.0                     0.304     84.0      0.0
#  1    50.0  28.2           82.0                     1.282    112.0      0.0
#  2    22.0  28.7           46.0                     0.654    139.0     83.0
#  3    65.0  21.9           50.0                     0.254    161.0      0.0
#  4    46.0  46.2           80.0                     0.238    134.0    370.0
#  ..    ...   ...            ...                       ...      ...      ...
#  609  26.0  28.6           64.0                     0.411    139.0    140.0
#  610  27.0  22.4          122.0                     0.207     96.0      0.0
#  611  38.0  45.6           86.0                     1.136    101.0      0.0
# ...
